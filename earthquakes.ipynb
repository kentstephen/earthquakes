# %%
! pip install pandas geopandas shapely keplergl
# Out:
# Collecting pandas
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting geopandas
#   Using cached geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting shapely
#   Using cached shapely-2.0.6-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Collecting keplergl
#   Using cached keplergl-0.3.2-py2.py3-none-any.whl
# Collecting numpy>=1.23.2 (from pandas)
#   Using cached numpy-2.1.1-cp311-cp311-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\project_files\earthquakes\.env\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Using cached pyogrio-0.9.0-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: packaging in c:\project_files\earthquakes\.env\lib\site-packages (from geopandas) (24.1)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Using cached pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Collecting ipywidgets<8,>=7.0.0 (from keplergl)
#   Using cached ipywidgets-7.8.4-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting traittypes>=0.2.1 (from keplergl)
#   Using cached traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\project_files\earthquakes\.env\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (0.2.2)
# Collecting ipython-genutils~=0.2.0 (from ipywidgets<8,>=7.0.0->keplergl)
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Requirement already satisfied: traitlets>=4.3.1 in c:\project_files\earthquakes\.env\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (5.14.3)
# Collecting widgetsnbextension~=3.6.9 (from ipywidgets<8,>=7.0.0->keplergl)
#   Using cached widgetsnbextension-3.6.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: ipython>=4.0.0 in c:\project_files\earthquakes\.env\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (8.27.0)
# Collecting jupyterlab-widgets<3,>=1.0.0 (from ipywidgets<8,>=7.0.0->keplergl)
#   Using cached jupyterlab_widgets-1.1.10-py3-none-any.whl.metadata (3.7 kB)
# Collecting certifi (from pyogrio>=0.7.2->geopandas)
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: six>=1.5 in c:\project_files\earthquakes\.env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: decorator in c:\project_files\earthquakes\.env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\project_files\earthquakes\.env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\project_files\earthquakes\.env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\project_files\earthquakes\.env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\project_files\earthquakes\.env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (2.18.0)
# Requirement already satisfied: stack-data in c:\project_files\earthquakes\.env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\project_files\earthquakes\.env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (4.12.2)
# Requirement already satisfied: colorama in c:\project_files\earthquakes\.env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.4.6)
# Collecting notebook>=4.4.1 (from widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached notebook-7.2.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\project_files\earthquakes\.env\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.8.4)
# Collecting jupyter-server<3,>=2.4.0 (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.3,>=4.2.0 (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached jupyterlab-4.2.5-py3-none-any.whl.metadata (16 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: tornado>=6.2.0 in c:\project_files\earthquakes\.env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl) (6.4.1)
# Requirement already satisfied: wcwidth in c:\project_files\earthquakes\.env\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\project_files\earthquakes\.env\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\project_files\earthquakes\.env\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (2.4.1)
# Requirement already satisfied: pure-eval in c:\project_files\earthquakes\.env\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.3)
# Collecting anyio>=3.1.0 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jinja2>=3.0.3 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\project_files\earthquakes\.env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\project_files\earthquakes\.env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl) (5.7.2)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting nbconvert>=6.4.4 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Collecting nbformat>=5.3.0 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached prometheus_client-0.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pywinpty>=2.0.1 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached pywinpty-2.0.13-cp311-none-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: pyzmq>=24 in c:\project_files\earthquakes\.env\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl) (26.2.0)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\project_files\earthquakes\.env\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl) (6.29.5)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: setuptools>=40.1.0 in c:\project_files\earthquakes\.env\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl) (73.0.1)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached babel-2.16.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached json5-0.9.25-py3-none-any.whl.metadata (30 kB)
# Collecting jsonschema>=4.18.0 (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting requests>=2.31 (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting idna>=2.8 (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting sniffio>=1.1 (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: debugpy>=1.6.5 in c:\project_files\earthquakes\.env\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl) (1.8.5)
# Requirement already satisfied: nest-asyncio in c:\project_files\earthquakes\.env\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl) (1.6.0)
# Requirement already satisfied: psutil in c:\project_files\earthquakes\.env\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl) (6.0.0)
# Collecting MarkupSafe>=2.0 (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting attrs>=22.2.0 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached rpds_py-0.20.0-cp311-none-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\project_files\earthquakes\.env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl) (4.3.4)
# Requirement already satisfied: pywin32>=300 in c:\project_files\earthquakes\.env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl) (306)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Collecting pyyaml>=5.3 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached PyYAML-6.0.2-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting beautifulsoup4 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting tinycss2 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached tinycss2-1.3.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached fastjsonschema-2.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting webencodings (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached webcolors-24.8.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached cffi-1.17.1-cp311-cp311-win_amd64.whl.metadata (1.6 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8,>=7.0.0->keplergl)
#   Using cached types_python_dateutil-2.9.0.20240906-py3-none-any.whl.metadata (1.9 kB)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Using cached geopandas-1.0.1-py3-none-any.whl (323 kB)
# Using cached shapely-2.0.6-cp311-cp311-win_amd64.whl (1.4 MB)
# Using cached ipywidgets-7.8.4-py2.py3-none-any.whl (124 kB)
# Using cached numpy-2.1.1-cp311-cp311-win_amd64.whl (12.9 MB)
# Using cached pyogrio-0.9.0-cp311-cp311-win_amd64.whl (15.9 MB)
# Using cached pyproj-3.6.1-cp311-cp311-win_amd64.whl (6.1 MB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Using cached jupyterlab_widgets-1.1.10-py3-none-any.whl (238 kB)
# Using cached widgetsnbextension-3.6.9-py2.py3-none-any.whl (1.5 MB)
# Using cached certifi-2024.8.30-py3-none-any.whl (167 kB)
# Using cached notebook-7.2.2-py3-none-any.whl (5.0 MB)
# Using cached jupyter_server-2.14.2-py3-none-any.whl (383 kB)
# Using cached jupyterlab-4.2.5-py3-none-any.whl (11.6 MB)
# Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Using cached anyio-4.4.0-py3-none-any.whl (86 kB)
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Using cached babel-2.16.0-py3-none-any.whl (9.6 MB)
# Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached json5-0.9.25-py3-none-any.whl (30 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Using cached nbconvert-7.16.4-py3-none-any.whl (257 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached prometheus_client-0.20.0-py3-none-any.whl (54 kB)
# Using cached pywinpty-2.0.13-cp311-none-win_amd64.whl (1.4 MB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached attrs-24.2.0-py3-none-any.whl (63 kB)
# Using cached bleach-6.1.0-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
# Using cached fastjsonschema-2.20.0-py3-none-any.whl (23 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl (17 kB)
# Using cached mistune-3.0.2-py3-none-any.whl (47 kB)
# Using cached nbclient-0.10.0-py3-none-any.whl (25 kB)
# Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Using cached python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Using cached PyYAML-6.0.2-cp311-cp311-win_amd64.whl (161 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Using cached rpds_py-0.20.0-cp311-none-win_amd64.whl (213 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Using cached tinycss2-1.3.0-py3-none-any.whl (22 kB)
# Using cached cffi-1.17.1-cp311-cp311-win_amd64.whl (181 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Using cached webcolors-24.8.0-py3-none-any.whl (15 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached types_python_dateutil-2.9.0.20240906-py3-none-any.whl (9.7 kB)
# Installing collected packages: webencodings, pytz, ipython-genutils, fastjsonschema, websocket-client, webcolors, urllib3, uri-template, tzdata, types-python-dateutil, traittypes, tinycss2, soupsieve, sniffio, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, pyyaml, pywinpty, python-json-logger, pycparser, prometheus-client, pandocfilters, overrides, numpy, mistune, MarkupSafe, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, json5, idna, h11, fqdn, defusedxml, charset-normalizer, certifi, bleach, babel, attrs, async-lru, terminado, shapely, requests, referencing, pyproj, pyogrio, pandas, jinja2, httpcore, cffi, beautifulsoup4, arrow, anyio, jupyter-server-terminals, jsonschema-specifications, isoduration, httpx, geopandas, argon2-cffi-bindings, jsonschema, argon2-cffi, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, widgetsnbextension, ipywidgets, keplergl
# Successfully installed MarkupSafe-2.1.5 anyio-4.4.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 attrs-24.2.0 babel-2.16.0 beautifulsoup4-4.12.3 bleach-6.1.0 certifi-2024.8.30 cffi-1.17.1 charset-normalizer-3.3.2 defusedxml-0.7.1 fastjsonschema-2.20.0 fqdn-1.5.1 geopandas-1.0.1 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 idna-3.10 ipython-genutils-0.2.0 ipywidgets-7.8.4 isoduration-20.11.0 jinja2-3.1.4 json5-0.9.25 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.2 jupyter-server-terminals-0.5.3 jupyterlab-4.2.5 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab-widgets-1.1.10 keplergl-0.3.2 mistune-3.0.2 nbclient-0.10.0 nbconvert-7.16.4 nbformat-5.10.4 notebook-7.2.2 notebook-shim-0.2.4 numpy-2.1.1 overrides-7.7.0 pandas-2.2.2 pandocfilters-1.5.1 prometheus-client-0.20.0 pycparser-2.22 pyogrio-0.9.0 pyproj-3.6.1 python-json-logger-2.0.7 pytz-2024.2 pywinpty-2.0.13 pyyaml-6.0.2 referencing-0.35.1 requests-2.32.3 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.20.0 send2trash-1.8.3 shapely-2.0.6 sniffio-1.3.1 soupsieve-2.6 terminado-0.18.1 tinycss2-1.3.0 traittypes-0.2.1 types-python-dateutil-2.9.0.20240906 tzdata-2024.1 uri-template-1.3.0 urllib3-2.2.3 webcolors-24.8.0 webencodings-0.5.1 websocket-client-1.8.0 widgetsnbextension-3.6.9

# %% [markdown]
# # Earthquakes from the US Geological Survey
# We are going to download and visualize

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point


# Load the earthquake data
df = pd.read_csv('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.csv')

# Convert the DataFrame to a GeoDataFrame
df['geometry'] = df.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)

# Aggregate the magnitude to help visualize
df["mag_value"] = abs(df["mag"]) * 100

df = df[['time','geometry', 'mag', 'depth', 'mag_value']]

# Create GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry='geometry')

# Set the CRS to WGS84 (EPSG:4326)
gdf.set_crs(epsg=4326, inplace=True)

# Display the first few rows to confirm the cleaning process
print(gdf.head())
# Out:
#                        time                     geometry   mag  depth  \
# 0  2024-09-17T18:17:27.990Z    POINT (-116.918 33.65033)  0.96  12.35
# 1  2024-09-17T18:08:36.050Z  POINT (-122.22567 37.80483)  2.44   8.98
# 2  2024-09-17T18:07:55.604Z    POINT (-139.6267 60.2009)  1.60   3.10
# 3  2024-09-17T18:06:56.377Z    POINT (-152.3411 59.1734)  1.90  61.10
# 4  2024-09-17T18:03:54.500Z      POINT (-116.956 32.898)  1.21   3.29
#
#    mag_value
# 0       96.0
# 1      244.0
# 2      160.0
# 3      190.0
# 4      121.0

# %% [markdown]
# Optionally, if you want to save the data and use in [Kepler.gl](kepler.gl) or [Four Square Studio](https://studio.foursquare.com/) you can uncomment and run this line:

# %%
# gdf.to_file('eathquakes.geojson', driver="GeoJSON")

# %% [markdown]
# Run this to get the map I set up:

# %%
kepler_config = {'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': 'e3iltfr', 'type': 'geojson', 'config': {'dataId': 'Earthquakes', 'label': 'Earthquakes', 'color': [241, 92, 23], 'highlightColor': [252, 242, 26, 255], 'columns': {'geojson': 'geometry'}, 'isVisible': True, 'visConfig': {'opacity': 0.51, 'strokeOpacity': 0.8, 'thickness': 0.5, 'strokeColor': None, 'colorRange': {'name': 'ColorBrewer Oranges-9', 'type': 'singlehue', 'category': 'ColorBrewer', 'colors': ['#fff5eb', '#fee6ce', '#fdd0a2', '#fdae6b', '#fd8d3c', '#f16913', '#d94801', '#a63603', '#7f2704']}, 'strokeColorRange': {'name': 'Global Warming', 'type': 'sequential', 'category': 'Uber', 'colors': ['#5A1846', '#900C3F', '#C70039', '#E3611C', '#F1920E', '#FFC300']}, 'radius': 10, 'sizeRange': [0, 10], 'radiusRange': [0, 100], 'heightRange': [0, 500], 'elevationScale': 5, 'enableElevationZoomFactor': True, 'stroked': True, 'filled': True, 'enable3d': False, 'wireframe': False}, 'hidden': False, 'textLabel': [{'field': None, 'color': [255, 255, 255], 'size': 18, 'offset': [0, 0], 'anchor': 'start', 'alignment': 'center'}]}, 'visualChannels': {'colorField': {'name': 'mag_value', 'type': 'real'}, 'colorScale': 'quantile', 'strokeColorField': None, 'strokeColorScale': 'quantile', 'sizeField': None, 'sizeScale': 'linear', 'heightField': None, 'heightScale': 'linear', 'radiusField': {'name': 'mag_value', 'type': 'real'}, 'radiusScale': 'sqrt'}}], 'interactionConfig': {'tooltip': {'fieldsToShow': {'Earthquakes': [{'name': 'time', 'format': None}, {'name': 'mag', 'format': None}, {'name': 'depth', 'format': None}, {'name': 'mag_value', 'format': None}]}, 'compareMode': False, 'compareType': 'absolute', 'enabled': True}, 'brush': {'size': 0.5, 'enabled': False}, 'geocoder': {'enabled': False}, 'coordinate': {'enabled': False}}, 'layerBlending': 'normal', 'splitMaps': [], 'animationConfig': {'currentTime': None, 'speed': 1}}, 'mapState': {'bearing': 0, 'dragRotate': False, 'latitude': 33.675672229699764, 'longitude': -117.63364321134047, 'pitch': 0, 'zoom': 6.716699698334183, 'isSplit': False}, 'mapStyle': {'styleType': 'dark', 'topLayerGroups': {'label': True}, 'visibleLayerGroups': {'label': True, 'road': True, 'border': False, 'building': True, 'water': True, 'land': True, '3d building': False}, 'threeDBuildingColor': [9.665468314072013, 17.18305478057247, 31.1442867897876], 'mapStyles': {}}}}

# %% [markdown]
# I have to restart VSCode after installing keplergl in order for it to render.
#
# Here we are visualizing magnitude by size and color using the `mag_value` to help Kepler.

# %%
# Load an empty map
from keplergl import KeplerGl

# Create an instance of KeplerGl
map_1 = KeplerGl()

# Add your data to the map
map_1.add_data(data=gdf, name='Earthquakes')

map_1.config = kepler_config
# Display the map
map_1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': 'e3iltfr', 'type': …

# %%
print(map_1.config)
# Out:
# {'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': 'e3iltfr', 'type': 'geojson', 'config': {'dataId': 'Earthquakes', 'label': 'Earthquakes', 'color': [241, 92, 23], 'highlightColor': [252, 242, 26, 255], 'columns': {'geojson': 'geometry'}, 'isVisible': True, 'visConfig': {'opacity': 0.51, 'strokeOpacity': 0.8, 'thickness': 0.5, 'strokeColor': None, 'colorRange': {'name': 'ColorBrewer Oranges-9', 'type': 'singlehue', 'category': 'ColorBrewer', 'colors': ['#fff5eb', '#fee6ce', '#fdd0a2', '#fdae6b', '#fd8d3c', '#f16913', '#d94801', '#a63603', '#7f2704']}, 'strokeColorRange': {'name': 'Global Warming', 'type': 'sequential', 'category': 'Uber', 'colors': ['#5A1846', '#900C3F', '#C70039', '#E3611C', '#F1920E', '#FFC300']}, 'radius': 10, 'sizeRange': [0, 10], 'radiusRange': [0, 100], 'heightRange': [0, 500], 'elevationScale': 5, 'enableElevationZoomFactor': True, 'stroked': True, 'filled': True, 'enable3d': False, 'wireframe': False}, 'hidden': False, 'textLabel': [{'field': None, 'color': [255, 255, 255], 'size': 18, 'offset': [0, 0], 'anchor': 'start', 'alignment': 'center'}]}, 'visualChannels': {'colorField': {'name': 'mag_value', 'type': 'real'}, 'colorScale': 'quantile', 'strokeColorField': None, 'strokeColorScale': 'quantile', 'sizeField': None, 'sizeScale': 'linear', 'heightField': None, 'heightScale': 'linear', 'radiusField': {'name': 'mag_value', 'type': 'real'}, 'radiusScale': 'sqrt'}}], 'interactionConfig': {'tooltip': {'fieldsToShow': {'Earthquakes': [{'name': 'time', 'format': None}, {'name': 'mag', 'format': None}, {'name': 'depth', 'format': None}, {'name': 'mag_value', 'format': None}]}, 'compareMode': False, 'compareType': 'absolute', 'enabled': True}, 'brush': {'size': 0.5, 'enabled': False}, 'geocoder': {'enabled': False}, 'coordinate': {'enabled': False}}, 'layerBlending': 'normal', 'splitMaps': [], 'animationConfig': {'currentTime': None, 'speed': 1}}, 'mapState': {'bearing': 0, 'dragRotate': False, 'latitude': 33.675672229699764, 'longitude': -117.63364321134047, 'pitch': 0, 'zoom': 6.716699698334183, 'isSplit': False}, 'mapStyle': {'styleType': 'dark', 'topLayerGroups': {'label': True}, 'visibleLayerGroups': {'label': True, 'road': True, 'border': False, 'building': True, 'water': True, 'land': True, '3d building': False}, 'threeDBuildingColor': [9.665468314072013, 17.18305478057247, 31.1442867897876], 'mapStyles': {}}}}
